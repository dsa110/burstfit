# %% [markdown]
# # injection tests

# %%
from burstfit.fit import BurstFit
from burstfit.data import BurstData
from burstfit.model import Model, SgramModel
from burstfit.utils.plotter import plot_me
from burstfit.utils.functions import pulse_fn_vec, sgram_fn_vec, sgram_fn, gauss_norm, gauss_norm3
from burstfit.utils.plotter import plot_fit_results, plot_2d_fit 
from burstfit.io import BurstIO
import logging
import numpy as np
import math
import matplotlib.pyplot as plt
# use Liam's function to read in filterbank files 
import sys
sys.path.insert(1, '/home/ubuntu/gechen/software')
import filplot_funcs_gc as ff

#from burstfit.utils.functions import gauss_norm2, pulse_fn_vec, sgram_fn_vec 
# %matplotlib inline 


# input variables 
# candidate = '220121aaat'
# datestring = '2022_1_21_5_1_21'
# beam = 100 
# corr = 'corr02'
# dm_heimdall = 313.4
# width_heimdall = 8 
# snr_heimdall = 9.4 
# mask_chans=[] 

# fil_file ='/data/dsa110/T1/'+corr + '/' + datestring + '/fil_'+candidate+'/'+candidate+'_'+str(beam)+'.fil'
# save_name = candidate + '_beam_'+str(beam)
# save_dir = '/home/ubuntu/gechen/burstfit_tests_outputs/' 

candidate = '220215aaac'
datestring = '2022_2_14_21_26_28'
beam = 129 
corr = 'corr09'
dm_heimdall = 759
width_heimdall = 16 
snr_heimdall = 10.5 
mask_chans=[] 

fil_file ='/data/dsa110/T1/'+corr + '/' + datestring + '/fil_'+candidate+'/'+candidate+'_'+str(beam)+'.fil'
save_name = candidate + '_beam_'+str(beam)
save_dir = '/home/ubuntu/gechen/burstfit_tests_outputs/' 


#data = ff.proc_cand_fil(fil_file, dm, width, nfreq_plot=64, ndm=64)[0]
#data_t = data.mean(0)

logging_format = "%(asctime)s - %(funcName)s -%(name)s - %(levelname)s - %(message)s"
logging.basicConfig(
    level=logging.INFO,
    format=logging_format,
)
# create burst object 
bd = BurstData(
    fp=fil_file,
    dm=dm_heimdall ,
    tcand=0.5, # pulse starting time in s.
    width=width_heimdall,  
    snr=snr_heimdall
)

bd.prepare_data()

# number of channels after binning 
# requires each channel bin to have SNR_min 
# snr_heimdall was calculated with all 256 channels binned into one 
SNR_min = 3 
n_per_bin = int(256 / (snr_heimdall / SNR_min)**2) 
if not math.log(n_per_bin, 2).is_integer():
    n_per_bin = 2 ** (int(np.log2(n_per_bin))+1)
nfreq = int(256 / n_per_bin) 
print(nfreq)
    
# read in data 
data = ff.proc_cand_fil(fil_file, bd.dm, bd.width, nfreq_plot=nfreq, ndm=64)[0]
# zoom in close to the burst 
data_burst = data[:,int(0.45/bd.tsamp): int(0.55/bd.tsamp)]
#data_burst = data 
    
# fit models  
# For pulse, we will use a gaussian convolved with an exponential model 
# S: Area of the pulse (fluence)
# mu: means of gaussians for each channel
# sigma: sigma of gaussian
# tau: scattering timescale for each channel
pnames = ['S', 'mu_t', 'sigma_t', 'tau']
pulseModel = Model(pulse_fn_vec, param_names=pnames)

# For spectra, we will use a normalized gaussian model  
snames = ['mu_f', 'sigma_f']
spectraModel = Model(gauss_norm, param_names=snames)


sgram_mask = np.full(np.shape(data_burst), False)
#sgramModel = SgramModel(pulseModel, spectraModel, sgram_fn_vec, 
#                        mask=sgram_mask, clip_fac=bd.clip_fac, other_param_names=["DM"])

sgramModel = SgramModel(pulseModel, spectraModel, sgram_fn, 
                        mask=sgram_mask, clip_fac=bd.clip_fac)#, other_param_names=["DM"])

#sgram_bounds=((0, 0.45, 0, -np.inf),(np.inf, 0.55, np.inf, np.inf)) # did not work when only set up bounds but do not chop data 

# Provide basic candidate information to `BurstFit`: sgram, model, DM, width, RFI mask, etc 
# initial fit: use heimdall results 
bf = BurstFit(
    sgram_model=sgramModel,
    sgram=data_burst, 
    width=width_heimdall,
    dm=dm_heimdall,
    foff=bd.foff * 1024 / nfreq,
    fch1=bd.fch1,
    tsamp=bd.tsamp,
    clip_fac=bd.clip_fac,
    mask= sgram_mask, 
    mcmcfit=False
)

print('bf.ncomponents=%d'%bf.ncomponents)
print(data_burst)

# Some setting up before we do the fitting 
bf.validate()
bf.precalc()

bf.fitcycle(plot=True)
# fit all componnts 
bf.fitall(plot=False) 
bf.calc_redchisq()
plot_fit_results(bf.sgram, bf.sgram_model.evaluate, bf.sgram_params['all'][1]['popt'], 
                 bf.tsamp, bf.fch1, bf.foff, show=True, save=True, outname=save_name+'2d_fit_res_curvfit', outdir=save_dir)
#dm_fit, dm_fit_err = bf.sgram_params['all'][1]['popt'][-1], bf.sgram_params['all'][1]['perr'][-1]
# Out:
# /home/ubuntu/gechen/software/filplot_funcs_gc.py:20: MatplotlibDeprecationWarning:
# The mpl_toolkits.axes_grid module was deprecated in Matplotlib 2.1 and will be removed two minor releases later. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist, which provide the same functionality instead.
#   from mpl_toolkits.axes_grid.inset_locator import inset_axes
# datacite/tind env not found. Cannot use datacite API
# 2022-02-15 19:18:38,242 - prepare_data -burstfit.data - INFO - Preparing data for burst fitting.
# 2022-02-15 19:18:38,246 - get_chunk -root - INFO - Padding with median in the beginning
# 2022-02-15 19:18:38,525 - crop_dedispersed_data -burstfit.data - INFO - Cropping data with time_window: 0.2s.
# 2022-02-15 19:18:38,529 - normalise_data -burstfit.data - INFO - Normalising data using off pulse mean and std.
# 2022-02-15 19:18:38,603 - normalise_data -burstfit.data - INFO - Off pulse mean and std are: (38.857433348395844, 19.230469453298358)
# 8
# bf.ncomponents=0
# [[ 0.          0.          0.         ...  0.          0.
#    0.        ]
#  [ 0.29181686 -1.6414697  -0.3830096  ...  1.714424   -1.057836
#    0.49244094]
#  [ 2.5169203  -0.16414697 -1.6049926  ...  0.9484048   0.9301662
#   -0.01823855]
#  ...
#  [ 0.07295422 -1.021359    0.01823855 ... -1.5137999  -0.16414697
#    0.25533974]
#  [ 1.1490289  -0.7113036  -1.0943131  ...  0.32829395 -0.25533974
#   -0.5106795 ]
#  [ 0.          0.          0.         ...  0.          0.
#    0.        ]]
# 2022-02-15 19:19:12,796 - fitcycle -burstfit.fit - INFO - Fitting component 1.
# 2022-02-15 19:19:12,799 - initial_profilefit -burstfit.fit - INFO - Running initial profile fit for component: 1
# 2022-02-15 19:19:13,118 - initial_profilefit -burstfit.fit - INFO - Converged parameters (profile fit) are:
# 2022-02-15 19:19:13,121 - initial_profilefit -burstfit.fit - INFO - S: 127.42976003566936 +- 13.283144384738673
# 2022-02-15 19:19:13,123 - initial_profilefit -burstfit.fit - INFO - mu_t: 191.44928572448717 +- 0.5943143150624352
# 2022-02-15 19:19:13,126 - initial_profilefit -burstfit.fit - INFO - sigma_t: 4.937610139799327 +- 0.5943143243940374
# 2022-02-15 19:19:13,129 - initial_profilefit -burstfit.fit - INFO - tau: 0.7167578565843367 +- 0.0
# 2022-02-15 19:19:13,414 - make_spectra -burstfit.fit - INFO - Making spectra using profile fit parameters.
# 2022-02-15 19:19:13,421 - initial_spectrafit -burstfit.fit - INFO - Running spectra profile fit for component: 1
# 2022-02-15 19:19:13,435 - initial_spectrafit -burstfit.fit - INFO - Converged parameters (spectra fit) are:
# 2022-02-15 19:19:13,437 - initial_spectrafit -burstfit.fit - INFO - mu_f: 3.727214312437325 +- 0.7359494014171205
# 2022-02-15 19:19:13,439 - initial_spectrafit -burstfit.fit - INFO - sigma_f: 2.276332925713462 +- 0.6249010556443929
# 2022-02-15 19:19:13,661 - sgram_fit -burstfit.fit - INFO - Running sgram profile fit for component: 1
# 2022-02-15 19:19:13,664 - sgram_fit -burstfit.fit - INFO - initial estimate for parameters: [3.727214312437325, 2.276332925713462, 127.42976003566936, 191.44928572448717, 4.937610139799327, 0.7167578565843367, 759]
# 2022-02-15 19:19:13,712 - sgram_fit -burstfit.fit - INFO - Converged parameters are:
# 2022-02-15 19:19:13,715 - sgram_fit -burstfit.fit - INFO - mu_f: 3.83266580401735 +- 0.3241614609506031
# 2022-02-15 19:19:13,717 - sgram_fit -burstfit.fit - INFO - sigma_f: 2.2702797056856867 +- 0.3227100414600296
# 2022-02-15 19:19:13,720 - sgram_fit -burstfit.fit - INFO - S: 124.39046035948938 +- 5.348516264490843
# 2022-02-15 19:19:13,722 - sgram_fit -burstfit.fit - INFO - mu_t: 191.49957702624397 +- 0.3957566332312093
# 2022-02-15 19:19:13,724 - sgram_fit -burstfit.fit - INFO - sigma_t: 4.962014380683647 +- 0.10021163579695705
# 2022-02-15 19:19:13,726 - sgram_fit -burstfit.fit - INFO - tau: 0.7152090989887882 +- 0.010117619834946521
# 2022-02-15 19:19:13,727 - sgram_fit -burstfit.fit - INFO - DM: 758.7332075711464 +- 0.5990151227915717
# 2022-02-15 19:19:14,363 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:19:14,365 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 19:19:14,368 - get_off_pulse_region -burstfit.fit - INFO - mu_t and sigma_t found in params. Using those to estimate off pulse region.
# 2022-02-15 19:19:14,370 - get_off_pulse_region -burstfit.fit - INFO - Using sgram fit parameters.
# 2022-02-15 19:19:14,372 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:19:14,373 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 19:19:14,377 - calc_redchisq -burstfit.fit - INFO - Reduced chi-square value of fit is: 1.0759937100688255
# 2022-02-15 19:19:14,379 - run_tests -burstfit.fit - INFO - Running statistical tests on the residual.
# 2022-02-15 19:19:14,380 - run_tests -burstfit.fit - INFO - Running off pulse - off pulse test
# 2022-02-15 19:19:14,384 - tests -root - INFO - P values: T-test (0.93808), Kruskal (0.81392), KS (0.99998), F-test (0.05557)
# 2022-02-15 19:19:14,386 - run_tests -burstfit.fit - INFO - Running on pulse - off pulse (L) test
# 2022-02-15 19:19:14,391 - tests -root - INFO - P values: T-test (0.00000), Kruskal (0.00000), KS (0.00007), F-test (0.00002)
# 2022-02-15 19:19:14,393 - run_tests -burstfit.fit - INFO - Running on pulse - off pulse (R) test
# 2022-02-15 19:19:14,397 - tests -root - INFO - P values: T-test (0.00000), Kruskal (0.00000), KS (0.00024), F-test (0.00499)
# 2022-02-15 19:19:14,399 - fitcycle -burstfit.fit - INFO - Fitting component 1.
# 2022-02-15 19:19:14,401 - initial_profilefit -burstfit.fit - INFO - Running initial profile fit for component: 1
# 2022-02-15 19:19:14,718 - initial_profilefit -burstfit.fit - INFO - Converged parameters (profile fit) are:
# 2022-02-15 19:19:14,721 - initial_profilefit -burstfit.fit - INFO - S: 127.42976003566936 +- 13.283144384738673
# 2022-02-15 19:19:14,724 - initial_profilefit -burstfit.fit - INFO - mu_t: 191.44928572448717 +- 0.5943143150624352
# 2022-02-15 19:19:14,726 - initial_profilefit -burstfit.fit - INFO - sigma_t: 4.937610139799327 +- 0.5943143243940374
# 2022-02-15 19:19:14,729 - initial_profilefit -burstfit.fit - INFO - tau: 0.7167578565843367 +- 0.0
# 2022-02-15 19:19:14,730 - make_spectra -burstfit.fit - INFO - Making spectra using profile fit parameters.
# 2022-02-15 19:19:14,732 - initial_spectrafit -burstfit.fit - INFO - Running spectra profile fit for component: 1
# 2022-02-15 19:19:14,741 - initial_spectrafit -burstfit.fit - INFO - Converged parameters (spectra fit) are:
# 2022-02-15 19:19:14,743 - initial_spectrafit -burstfit.fit - INFO - mu_f: 3.727214312437325 +- 0.7359494014171205
# 2022-02-15 19:19:14,745 - initial_spectrafit -burstfit.fit - INFO - sigma_f: 2.276332925713462 +- 0.6249010556443929
# 2022-02-15 19:19:14,748 - sgram_fit -burstfit.fit - INFO - Running sgram profile fit for component: 1
# 2022-02-15 19:19:14,750 - sgram_fit -burstfit.fit - INFO - initial estimate for parameters: [3.727214312437325, 2.276332925713462, 127.42976003566936, 191.44928572448717, 4.937610139799327, 0.7167578565843367, 759]
# 2022-02-15 19:19:14,802 - sgram_fit -burstfit.fit - INFO - Converged parameters are:
# 2022-02-15 19:19:14,804 - sgram_fit -burstfit.fit - INFO - mu_f: 3.83266580401735 +- 0.3241614609506031
# 2022-02-15 19:19:14,806 - sgram_fit -burstfit.fit - INFO - sigma_f: 2.2702797056856867 +- 0.3227100414600296
# 2022-02-15 19:19:14,808 - sgram_fit -burstfit.fit - INFO - S: 124.39046035948938 +- 5.348516264490843
# 2022-02-15 19:19:14,809 - sgram_fit -burstfit.fit - INFO - mu_t: 191.49957702624397 +- 0.3957566332312093
# 2022-02-15 19:19:14,811 - sgram_fit -burstfit.fit - INFO - sigma_t: 4.962014380683647 +- 0.10021163579695705
# 2022-02-15 19:19:14,813 - sgram_fit -burstfit.fit - INFO - tau: 0.7152090989887882 +- 0.010117619834946521
# 2022-02-15 19:19:14,814 - sgram_fit -burstfit.fit - INFO - DM: 758.7332075711464 +- 0.5990151227915717
# 2022-02-15 19:19:14,816 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:19:14,818 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 19:19:14,822 - get_off_pulse_region -burstfit.fit - INFO - mu_t and sigma_t found in params. Using those to estimate off pulse region.
# 2022-02-15 19:19:14,824 - get_off_pulse_region -burstfit.fit - INFO - Using sgram fit parameters.
# 2022-02-15 19:19:14,826 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:19:14,828 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 19:19:14,833 - calc_redchisq -burstfit.fit - INFO - Reduced chi-square value of fit is: 1.0759937100688255
# 2022-02-15 19:19:14,834 - run_tests -burstfit.fit - INFO - Running statistical tests on the residual.
# 2022-02-15 19:19:14,836 - run_tests -burstfit.fit - INFO - Running off pulse - off pulse test
# 2022-02-15 19:19:14,841 - tests -root - INFO - P values: T-test (0.93808), Kruskal (0.81392), KS (0.99998), F-test (0.05557)
# 2022-02-15 19:19:14,844 - run_tests -burstfit.fit - INFO - Running on pulse - off pulse (L) test
# 2022-02-15 19:19:14,849 - tests -root - INFO - P values: T-test (0.56554), Kruskal (0.39106), KS (0.00001), F-test (0.01299)
# 2022-02-15 19:19:14,852 - run_tests -burstfit.fit - INFO - On pulse residual is similar to left off pulse region.
# 2022-02-15 19:19:14,853 - run_tests -burstfit.fit - INFO - Running on pulse - off pulse (R) test
# 2022-02-15 19:19:14,858 - tests -root - INFO - P values: T-test (0.63370), Kruskal (0.45398), KS (0.00007), F-test (0.26247)
# 2022-02-15 19:19:14,860 - run_tests -burstfit.fit - INFO - On pulse residual is similar to right off pulse region.
# 2022-02-15 19:19:14,862 - fitall -burstfit.fit - INFO - On pulse residual looks like noise. Terminating individual component fitting.
# 2022-02-15 19:19:14,863 - fitall -burstfit.fit - INFO - Final number of components = 1. Terminating fitting.
# 2022-02-15 19:19:14,866 - get_off_pulse_region -burstfit.fit - INFO - mu_t and sigma_t found in params. Using those to estimate off pulse region.
# 2022-02-15 19:19:14,868 - get_off_pulse_region -burstfit.fit - INFO - Using sgram all-component-fit parameters.
# 2022-02-15 19:19:14,870 - get_off_pulse_region -burstfit.fit - INFO - mu_t and sigma_t found in params. Using those to estimate off pulse region.
# 2022-02-15 19:19:14,872 - get_off_pulse_region -burstfit.fit - INFO - Using sgram all-component-fit parameters.
# 2022-02-15 19:19:14,874 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:19:14,876 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 19:19:14,881 - calc_redchisq -burstfit.fit - INFO - Reduced chi-square value of fit is: 1.0759937100688255

# %%
bf.sgram_params
plot_me(bf.model[:,int(382/2-30): int(382/2+30)]) 
bd.tsamp*3*1e3

dm_diff = 103.46597098341815 - 103
print('expected despersion in tsamp: %.1f time samples'%(4.149e3*dm_diff*(1/1280**2 - 1/1530**2) / bd.tsamp)) 

plot_me(bf.model)

bf.sgram_params

sgramModel.nparams
# Out:
# 2022-02-15 19:19:17,276 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:19:17,280 - model -burstfit.fit - INFO - Found 1 components.
# expected despersion in tsamp: 1.4 time samples
# 2022-02-15 19:19:17,515 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:19:17,518 - model -burstfit.fit - INFO - Found 1 components.
# 7

# %%
pnames = ['S', 'mu_t', 'sigma_t', 'tau']
pulseModel = Model(pulse_fn_vec, param_names=pnames)

# For spectra, we will use a normalized gaussian model  
snames = ['mu_f', 'sigma_f']
spectraModel = Model(gauss_norm, param_names=snames)


sgram_mask = np.full(np.shape(data_burst), False)
#sgramModel = SgramModel(pulseModel, spectraModel, sgram_fn_vec, 
#                        mask=sgram_mask, clip_fac=bd.clip_fac, other_param_names=["DM"])

sgramModel = SgramModel(pulseModel, spectraModel, sgram_fn, 
                        mask=sgram_mask, clip_fac=bd.clip_fac)#, other_param_names=["DM"])


bf = BurstFit(
    sgram_model=sgramModel,
    sgram=data_burst, 
    width=width_heimdall,
    dm=dm_heimdall,
    foff=bd.foff * 1024 / nfreq,
    fch1=bd.fch1,
    tsamp=bd.tsamp,
    clip_fac=bd.clip_fac,
    mask= sgram_mask, 
    mcmcfit=False
)

print(np.shape(data_burst))

# Some setting up before we do the fitting 
bf.validate()
bf.precalc()
print('bf.ncomponents=%d'%bf.ncomponents)
# Out:
# (8, 382)
# bf.ncomponents=0

# %%
bf.fitcycle(plot=False)
print('bf.ncomponents=%d'%bf.ncomponents)

# fit all componnts 
bf.fitall(plot=False) 
print('bf.ncomponents=%d'%bf.ncomponents)

bf.sgram_params
# Out:
# 2022-02-15 19:19:17,792 - fitcycle -burstfit.fit - INFO - Fitting component 1.
# 2022-02-15 19:19:17,795 - initial_profilefit -burstfit.fit - INFO - Running initial profile fit for component: 1
# 2022-02-15 19:19:18,133 - initial_profilefit -burstfit.fit - INFO - Converged parameters (profile fit) are:
# 2022-02-15 19:19:18,136 - initial_profilefit -burstfit.fit - INFO - S: 127.42976003566936 +- 13.283144384738673
# 2022-02-15 19:19:18,138 - initial_profilefit -burstfit.fit - INFO - mu_t: 191.44928572448717 +- 0.5943143150624352
# 2022-02-15 19:19:18,140 - initial_profilefit -burstfit.fit - INFO - sigma_t: 4.937610139799327 +- 0.5943143243940374
# 2022-02-15 19:19:18,142 - initial_profilefit -burstfit.fit - INFO - tau: 0.7167578565843367 +- 0.0
# 2022-02-15 19:19:18,144 - make_spectra -burstfit.fit - INFO - Making spectra using profile fit parameters.
# 2022-02-15 19:19:18,146 - initial_spectrafit -burstfit.fit - INFO - Running spectra profile fit for component: 1
# 2022-02-15 19:19:18,162 - initial_spectrafit -burstfit.fit - INFO - Converged parameters (spectra fit) are:
# 2022-02-15 19:19:18,165 - initial_spectrafit -burstfit.fit - INFO - mu_f: 3.727214312437325 +- 0.7359494014171205
# 2022-02-15 19:19:18,168 - initial_spectrafit -burstfit.fit - INFO - sigma_f: 2.276332925713462 +- 0.6249010556443929
# 2022-02-15 19:19:18,170 - sgram_fit -burstfit.fit - INFO - Running sgram profile fit for component: 1
# 2022-02-15 19:19:18,173 - sgram_fit -burstfit.fit - INFO - initial estimate for parameters: [3.727214312437325, 2.276332925713462, 127.42976003566936, 191.44928572448717, 4.937610139799327, 0.7167578565843367, 759]
# 2022-02-15 19:19:18,229 - sgram_fit -burstfit.fit - INFO - Converged parameters are:
# 2022-02-15 19:19:18,232 - sgram_fit -burstfit.fit - INFO - mu_f: 3.83266580401735 +- 0.3241614609506031
# 2022-02-15 19:19:18,234 - sgram_fit -burstfit.fit - INFO - sigma_f: 2.2702797056856867 +- 0.3227100414600296
# 2022-02-15 19:19:18,236 - sgram_fit -burstfit.fit - INFO - S: 124.39046035948938 +- 5.348516264490843
# 2022-02-15 19:19:18,239 - sgram_fit -burstfit.fit - INFO - mu_t: 191.49957702624397 +- 0.3957566332312093
# 2022-02-15 19:19:18,241 - sgram_fit -burstfit.fit - INFO - sigma_t: 4.962014380683647 +- 0.10021163579695705
# 2022-02-15 19:19:18,244 - sgram_fit -burstfit.fit - INFO - tau: 0.7152090989887882 +- 0.010117619834946521
# 2022-02-15 19:19:18,247 - sgram_fit -burstfit.fit - INFO - DM: 758.7332075711464 +- 0.5990151227915717
# 2022-02-15 19:19:18,250 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:19:18,252 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 19:19:18,257 - get_off_pulse_region -burstfit.fit - INFO - mu_t and sigma_t found in params. Using those to estimate off pulse region.
# 2022-02-15 19:19:18,259 - get_off_pulse_region -burstfit.fit - INFO - Using sgram fit parameters.
# 2022-02-15 19:19:18,261 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:19:18,263 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 19:19:18,269 - calc_redchisq -burstfit.fit - INFO - Reduced chi-square value of fit is: 1.0759937100688255
# bf.ncomponents=1
# 2022-02-15 19:19:18,273 - run_tests -burstfit.fit - INFO - Running statistical tests on the residual.
# 2022-02-15 19:19:18,275 - run_tests -burstfit.fit - INFO - Running off pulse - off pulse test
# 2022-02-15 19:19:18,280 - tests -root - INFO - P values: T-test (0.93808), Kruskal (0.81392), KS (0.99998), F-test (0.05557)
# 2022-02-15 19:19:18,282 - run_tests -burstfit.fit - INFO - Running on pulse - off pulse (L) test
# 2022-02-15 19:19:18,286 - tests -root - INFO - P values: T-test (0.00000), Kruskal (0.00000), KS (0.00007), F-test (0.00002)
# 2022-02-15 19:19:18,288 - run_tests -burstfit.fit - INFO - Running on pulse - off pulse (R) test
# 2022-02-15 19:19:18,292 - tests -root - INFO - P values: T-test (0.00000), Kruskal (0.00000), KS (0.00024), F-test (0.00499)
# 2022-02-15 19:19:18,294 - fitcycle -burstfit.fit - INFO - Fitting component 1.
# 2022-02-15 19:19:18,296 - initial_profilefit -burstfit.fit - INFO - Running initial profile fit for component: 1
# 2022-02-15 19:19:18,660 - initial_profilefit -burstfit.fit - INFO - Converged parameters (profile fit) are:
# 2022-02-15 19:19:18,663 - initial_profilefit -burstfit.fit - INFO - S: 127.42976003566936 +- 13.283144384738673
# 2022-02-15 19:19:18,665 - initial_profilefit -burstfit.fit - INFO - mu_t: 191.44928572448717 +- 0.5943143150624352
# 2022-02-15 19:19:18,668 - initial_profilefit -burstfit.fit - INFO - sigma_t: 4.937610139799327 +- 0.5943143243940374
# 2022-02-15 19:19:18,671 - initial_profilefit -burstfit.fit - INFO - tau: 0.7167578565843367 +- 0.0
# 2022-02-15 19:19:18,674 - make_spectra -burstfit.fit - INFO - Making spectra using profile fit parameters.
# 2022-02-15 19:19:18,677 - initial_spectrafit -burstfit.fit - INFO - Running spectra profile fit for component: 1
# 2022-02-15 19:19:18,689 - initial_spectrafit -burstfit.fit - INFO - Converged parameters (spectra fit) are:
# 2022-02-15 19:19:18,692 - initial_spectrafit -burstfit.fit - INFO - mu_f: 3.727214312437325 +- 0.7359494014171205
# 2022-02-15 19:19:18,694 - initial_spectrafit -burstfit.fit - INFO - sigma_f: 2.276332925713462 +- 0.6249010556443929
# 2022-02-15 19:19:18,696 - sgram_fit -burstfit.fit - INFO - Running sgram profile fit for component: 1
# 2022-02-15 19:19:18,698 - sgram_fit -burstfit.fit - INFO - initial estimate for parameters: [3.727214312437325, 2.276332925713462, 127.42976003566936, 191.44928572448717, 4.937610139799327, 0.7167578565843367, 759]
# 2022-02-15 19:19:18,748 - sgram_fit -burstfit.fit - INFO - Converged parameters are:
# 2022-02-15 19:19:18,751 - sgram_fit -burstfit.fit - INFO - mu_f: 3.83266580401735 +- 0.3241614609506031
# 2022-02-15 19:19:18,754 - sgram_fit -burstfit.fit - INFO - sigma_f: 2.2702797056856867 +- 0.3227100414600296
# 2022-02-15 19:19:18,757 - sgram_fit -burstfit.fit - INFO - S: 124.39046035948938 +- 5.348516264490843
# 2022-02-15 19:19:18,759 - sgram_fit -burstfit.fit - INFO - mu_t: 191.49957702624397 +- 0.3957566332312093
# 2022-02-15 19:19:18,761 - sgram_fit -burstfit.fit - INFO - sigma_t: 4.962014380683647 +- 0.10021163579695705
# 2022-02-15 19:19:18,762 - sgram_fit -burstfit.fit - INFO - tau: 0.7152090989887882 +- 0.010117619834946521
# 2022-02-15 19:19:18,764 - sgram_fit -burstfit.fit - INFO - DM: 758.7332075711464 +- 0.5990151227915717
# 2022-02-15 19:19:18,765 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:19:18,767 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 19:19:18,772 - get_off_pulse_region -burstfit.fit - INFO - mu_t and sigma_t found in params. Using those to estimate off pulse region.
# 2022-02-15 19:19:18,774 - get_off_pulse_region -burstfit.fit - INFO - Using sgram fit parameters.
# 2022-02-15 19:19:18,776 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:19:18,778 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 19:19:18,785 - calc_redchisq -burstfit.fit - INFO - Reduced chi-square value of fit is: 1.0759937100688255
# 2022-02-15 19:19:18,787 - run_tests -burstfit.fit - INFO - Running statistical tests on the residual.
# 2022-02-15 19:19:18,789 - run_tests -burstfit.fit - INFO - Running off pulse - off pulse test
# 2022-02-15 19:19:18,793 - tests -root - INFO - P values: T-test (0.93808), Kruskal (0.81392), KS (0.99998), F-test (0.05557)
# 2022-02-15 19:19:18,795 - run_tests -burstfit.fit - INFO - Running on pulse - off pulse (L) test
# 2022-02-15 19:19:18,800 - tests -root - INFO - P values: T-test (0.56554), Kruskal (0.39106), KS (0.00001), F-test (0.01299)
# 2022-02-15 19:19:18,802 - run_tests -burstfit.fit - INFO - On pulse residual is similar to left off pulse region.
# 2022-02-15 19:19:18,804 - run_tests -burstfit.fit - INFO - Running on pulse - off pulse (R) test
# 2022-02-15 19:19:18,808 - tests -root - INFO - P values: T-test (0.63370), Kruskal (0.45398), KS (0.00007), F-test (0.26247)
# 2022-02-15 19:19:18,810 - run_tests -burstfit.fit - INFO - On pulse residual is similar to right off pulse region.
# 2022-02-15 19:19:18,812 - fitall -burstfit.fit - INFO - On pulse residual looks like noise. Terminating individual component fitting.
# 2022-02-15 19:19:18,814 - fitall -burstfit.fit - INFO - Final number of components = 1. Terminating fitting.
# 2022-02-15 19:19:18,817 - get_off_pulse_region -burstfit.fit - INFO - mu_t and sigma_t found in params. Using those to estimate off pulse region.
# 2022-02-15 19:19:18,819 - get_off_pulse_region -burstfit.fit - INFO - Using sgram all-component-fit parameters.
# bf.ncomponents=1
# {1: {'popt': [3.83266580401735,
#    2.2702797056856867,
#    124.39046035948938,
#    191.49957702624397,
#    4.962014380683647,
#    0.7152090989887882,
#    758.7332075711464],
#   'perr': array([0.32416146, 0.32271004, 5.34851626, 0.39575663, 0.10021164,
#          0.01011762, 0.59901512])},
#  'all': {1: {'popt': [3.83266580401735,
#     2.2702797056856867,
#     124.39046035948938,
#     191.49957702624397,
#     4.962014380683647,
#     0.7152090989887882,
#     758.7332075711464],
#    'perr': array([0.32416146, 0.32271004, 5.34851626, 0.39575663, 0.10021164,
#           0.01011762, 0.59901512])}}}

# %%
# MCMC 
# nwalker >= dimention + 1 
# nstep until getting smooth parameter distributions 
mcmc_kwargs = {}
mcmc_kwargs = {'nwalkers':60, 'nsteps':int(1e4),
           'skip':500, 'ncores':4, 
           'start_pos_dev':0.01,
           'prior_range':0.8, 
           'save_results':True,
           'outname':'test_file'}

bf.run_mcmc(plot=True, **mcmc_kwargs)
# Out:
# 2022-02-15 19:19:18,996 - set_initial_pos -root - INFO - Setting initial positions for MCMC.
# 2022-02-15 19:19:19,000 - set_initial_pos -burstfit.mcmc - INFO - Initial guess for MCMC is: [3.83266580e+00 2.27027971e+00 1.24390460e+02 1.91499577e+02
#  4.96201438e+00 7.15209099e-01 7.58733208e+02]
# 2022-02-15 19:19:19,003 - set_priors -burstfit.mcmc - INFO - Setting priors for MCMC.
# 2022-02-15 19:19:19,005 - set_priors -burstfit.mcmc - INFO - Found tau in param_names. Setting its min value of prior to 0.
# 2022-02-15 19:19:19,007 - set_priors -burstfit.mcmc - INFO - Found sigma_t in param_names. Setting its min value of prior to 0.
# 2022-02-15 19:19:19,009 - set_priors -burstfit.mcmc - INFO - Found sigma_t and tau in param_names. Setting its max value of prior to 2*(max_tau_prior(1.2873763781798186) + max_sigma_t_prior(8.931625885230565))
# 2022-02-15 19:19:19,011 - set_priors -burstfit.mcmc - INFO - Found S and sigma_t in param_names. Setting its max value of prior to 500*max(ts)*max_sigma_t_prior. Setting its min value of prior to 0.
# 2022-02-15 19:19:19,013 - set_priors -burstfit.mcmc - INFO - Found mu_f in param_names. Setting its priors to (-2*nf, 3*nf)
# 2022-02-15 19:19:19,014 - set_priors -burstfit.mcmc - INFO - Found sigma_f in param_names. Setting its priors to (0, 5*nf)
# 2022-02-15 19:19:19,024 - run_mcmc -burstfit.mcmc - INFO - Running MCMC with the following parameters: nwalkers=60, nsteps=10000, start_pos_dev=0.01, ncores=4, skip=500
# 2022-02-15 19:19:19,027 - run_mcmc -burstfit.mcmc - INFO - Priors used in MCMC are:
# 2022-02-15 19:19:19,029 - run_mcmc -burstfit.mcmc - INFO - mu_f_1: [-16.0, 24.0]
# 2022-02-15 19:19:19,032 - run_mcmc -burstfit.mcmc - INFO - sigma_f_1: [0.0, 40.0]
# 2022-02-15 19:19:19,034 - run_mcmc -burstfit.mcmc - INFO - S_1: [0.0, 54164.22549244571]
# 2022-02-15 19:19:19,036 - run_mcmc -burstfit.mcmc - INFO - mu_t_1: [38.29991540524878, 344.69923864723916]
# 2022-02-15 19:19:19,039 - run_mcmc -burstfit.mcmc - INFO - sigma_t_1: [0.0, 20.438004526820766]
# 2022-02-15 19:19:19,042 - run_mcmc -burstfit.mcmc - INFO - tau_1: [0.0, 20.438004526820766]
# 2022-02-15 19:19:19,044 - run_mcmc -burstfit.mcmc - INFO - DM_1: [151.74664151422925, 1365.7197736280636]
# 100%|██████████| 10000/10000 [09:35<00:00, 17.37it/s]
# 2022-02-15 19:28:54,979 - get_chain -burstfit.mcmc - INFO - Using autocorrelation time to estimate burnin and thin values.
# 2022-02-15 19:28:55,669 - get_chain -burstfit.mcmc - INFO - Burnin is: 995, thin is: 71
# 2022-02-15 19:28:55,671 - get_chain -burstfit.mcmc - INFO - Discarding 500 steps/iterations.
# 2022-02-15 19:28:55,722 - print_results -burstfit.mcmc - INFO - MCMC fit results are:
# 2022-02-15 19:28:55,723 - print_results -burstfit.mcmc - INFO - mu_f_1: 5.632104869440035 + 13.108 - 2.081
# 2022-02-15 19:28:55,724 - print_results -burstfit.mcmc - INFO - sigma_f_1: 16.317420041759227 + 16.955 - 13.396
# 2022-02-15 19:28:55,726 - print_results -burstfit.mcmc - INFO - S_1: 896.6831592938338 + 609.007 - 730.241
# 2022-02-15 19:28:55,727 - print_results -burstfit.mcmc - INFO - mu_t_1: 187.8409601453409 + 2.088 - 1.932
# 2022-02-15 19:28:55,729 - print_results -burstfit.mcmc - INFO - sigma_t_1: 4.159331563678033 + 0.907 - 1.056
# 2022-02-15 19:28:55,731 - print_results -burstfit.mcmc - INFO - tau_1: 2.702264261982296 + 1.998 - 1.707
# 2022-02-15 19:28:55,732 - print_results -burstfit.mcmc - INFO - DM_1: 759.5966621560369 + 1.139 - 1.115
# 2022-02-15 19:28:55,734 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:28:55,736 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 19:28:55,742 - get_off_pulse_region -burstfit.fit - INFO - mu_t and sigma_t found in params. Using those to estimate off pulse region.
# 2022-02-15 19:28:55,743 - get_off_pulse_region -burstfit.fit - INFO - Using MCMC parameters
# 2022-02-15 19:28:55,745 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:28:55,747 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 19:28:55,751 - calc_redchisq -burstfit.fit - INFO - Reduced chi-square value of fit is: 1.0777122804724124
# 2022-02-15 19:28:55,753 - plot -burstfit.mcmc - INFO - Plotting MCMC results.

# %%
# save fitting results 
bd.prepare_data()
bio = BurstIO(bf, bd)
d = bio.save_results(outname=save_name+"_fit_results.json", outdir=save_dir)  
print(d['param_names'])
# Out:
# 2022-02-15 19:31:28,858 - prepare_data -burstfit.data - INFO - Preparing data for burst fitting.
# 2022-02-15 19:31:28,862 - get_chunk -root - INFO - Padding with median in the beginning
# 2022-02-15 19:31:29,110 - crop_dedispersed_data -burstfit.data - INFO - Cropping data with time_window: 0.2s.
# 2022-02-15 19:31:29,113 - normalise_data -burstfit.data - INFO - Normalising data using off pulse mean and std.
# 2022-02-15 19:31:29,183 - normalise_data -burstfit.data - INFO - Off pulse mean and std are: (38.857433348395844, 19.230469453298358)
# 2022-02-15 19:31:29,193 - set_attributes_to_save -burstfit.io - INFO - Setting attributes to be saved.
# 2022-02-15 19:31:29,196 - set_attributes_to_save -burstfit.io - INFO - Reading attributes from BurstData object.
# 2022-02-15 19:31:29,199 - set_attributes_to_save -burstfit.io - INFO - Reading attributes from BurstFit object.
# 2022-02-15 19:31:29,201 - set_attributes_to_save -burstfit.io - INFO - Copied necessary attributes
# 2022-02-15 19:31:29,204 - save_results -burstfit.io - INFO - Preparing dictionary to be saved.
# 2022-02-15 19:31:29,206 - save_results -burstfit.io - INFO - Writing JSON file: /home/ubuntu/gechen/burstfit_tests_outputs//220215aaac_beam_129_fit_results.json.
# ['mu_f', 'sigma_f', 'S', 'mu_t', 'sigma_t', 'tau', 'DM']

# %%
# do not delete this cell. 
# fit again using the new DM result dm_fit
# data, datadm, tsdm0, dms, datadm0 = ff.proc_cand_fil(fil_file, dm_fit, bd.width, nfreq_plot=nfreq, ndm=32)
# data_burst = data[:,int(0.45/bd.tsamp): int(0.55/bd.tsamp)]
# bf.sgram = data_burst
# bf.dm = dm_fit
# bd.dm = dm_fit 

# plt.plot(range(len(data_burst.mean(0))), data_burst.mean(0))
# plt.xlabel('Time Sample using new DM')

# bf.fitall(plot=False)
# plot_fit_results(bf.sgram, bf.sgram_model.evaluate, bf.sgram_params['all'][1]['popt'], 
#                  bf.tsamp, bf.fch1, bf.foff, show=True, save=True, outname=save_name+'2d_fit_res'+'_dm_burstfit', outdir=save_dir)

# %%
# saving key burst paramters 
mu_f_mcmc, sigma_f_mcmc, s_mcmc, mu_t_mcmc, sigma_t_mcmc, tau_mcmc, dm_mcmc = bf.mcmc_params[1]['popt']
mu_f_mcmc_err, sigma_f_mcmc_err, s_mcmc_err, mu_t_mcmc_err, sigma_t_mcmc_err, tau_mcmc_err, dm_mcmc_err = bf.mcmc_params[1]['perr']

t0 = 0.45 + mu_t_mcmc * bd.tsamp
t0_err = [i * bd.tsamp for i in mu_t_mcmc_err] 

width_ms = sigma_t_mcmc * bd.tsamp * 1e3 # in ms
width_ms_err = [i * bd.tsamp for i in sigma_t_mcmc_err] 

# with open(save_dir+save_name+"_fit_key_results.txt") as f:
#     print('mu_f_mcmc, sigma_f_mcmc, s_mcmc, mu_t_mcmc, sigma_t_mcmc, tau_mcmc, dm_mcmc')
#     print(bf.mcmc_params[1]['popt'])
#     print('lower, upper bounds')
#     print(bf.mcmc_params[1]['perr'])

#outname=save_name+"_fit_results.json", outdir=save_dir

# %%
rms_res = np.sqrt(sum(bf.residual.mean(0)**2) / len(bf.residual.mean(0)))

#rms_res = np.sqrt(sum(data.mean(0)**2) / len(data.mean(0)))

snr_mcmc = max(bf.model.mean(0)) / rms_res * np.sqrt(bf.width)

print("MCMC result SNR = %.2f"%snr_mcmc)
# Out:
# 2022-02-15 19:36:00,044 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:36:00,048 - model -burstfit.fit - INFO - Found 1 components.
# MCMC result SNR = 20.09

# %%
print(np.sqrt(sum(data.mean(0)**2) / len(data.mean(0))))
print(np.sqrt(sum(bf.residual.mean(0)**2) / len(bf.residual.mean(0))))
print(max(data.mean(0)))
# Out:
# 0.3575047825150488
# 0.3271696927017047
# 1.5160797

# %%
sum(bf.residual.mean(0)**2) / len(bf.residual.mean(0))
dm_mcmc
sigma_t_mcmc
# Out:
# 4.159331563678033

# %%
data_mcmc_dm = ff.proc_cand_fil(fil_file, dm_mcmc, sigma_f_mcmc, nfreq_plot=nfreq, ndm=32)[0]

# %%
#snr_himdall?  
max(data_mcmc_dm.mean(0)) / np.sqrt(sum(data_mcmc_dm.mean(0)**2) / len(data_mcmc_dm.mean(0)))
# Out:
# 4.151593053359835

# %%
fig, ax = plt.subplots(2, 1, sharex=True)
ax[0].plot(range(len(data.mean(0)[int(0.48/bd.tsamp): int(0.52/bd.tsamp)])), data.mean(0)[int(0.48/bd.tsamp): int(0.52/bd.tsamp)])
ax[0].set_title('Using heimdall DM: SNR=%d?'%bd.snr)

ax[1].plot(range(len(data_mcmc_dm.mean(0)[int(0.48/bd.tsamp): int(0.52/bd.tsamp)])), data_mcmc_dm.mean(0)[int(0.48/bd.tsamp): int(0.52/bd.tsamp)])
ax[1].set_xlabel('Time Sample')
ax[1].set_title('Using burstfit DM: SNR=?')
fig.savefig(save_name + 'burst.pdf')

# %% [markdown]
# ### 220215_aaax

# %%
candidate = '220215aaab'
datestring = '2022_2_14_21_26_28'
beam = 65 
corr = 'corr02'
dm_heimdall = 759.7
width_heimdall = 16 
snr_heimdall = 11.2 
mask_chans=[] 

fil_file ='/data/dsa110/T1/'+corr + '/' + datestring + '/fil_'+candidate+'/'+candidate+'_'+str(beam)+'.fil'
save_name = candidate + '_beam_'+str(beam)


# create burst object 
bd = BurstData(
    fp=fil_file,
    dm=dm_heimdall ,
    tcand=0.5, # pulse starting time in s.
    width=width_heimdall,  
    snr=snr_heimdall
)

bd.prepare_data()

# number of channels after binning 
# requires each channel bin to have SNR_min 
# snr_heimdall was calculated with all 256 channels binned into one 
SNR_min = 3 
n_per_bin = int(256 / (snr_heimdall / SNR_min)**2) 
if not math.log(n_per_bin, 2).is_integer():
    n_per_bin = 2 ** (int(np.log2(n_per_bin))+1)
nfreq = int(256 / n_per_bin) 
print(nfreq)
    
# read in data 
data = ff.proc_cand_fil(fil_file, bd.dm, bd.width, nfreq_plot=nfreq, ndm=64)[0]
# zoom in close to the burst 
data_burst = data[:,int(0.45/bd.tsamp): int(0.55/bd.tsamp)]
#data_burst = data 
    
# fit models  
# For pulse, we will use a gaussian convolved with an exponential model 
# S: Area of the pulse (fluence)
# mu: means of gaussians for each channel
# sigma: sigma of gaussian
# tau: scattering timescale for each channel
pnames = ['S', 'mu_t', 'sigma_t', 'tau']
pulseModel = Model(pulse_fn_vec, param_names=pnames)

# For spectra, we will use a normalized gaussian model  
snames = ['mu_f', 'sigma_f']
spectraModel = Model(gauss_norm, param_names=snames)


sgram_mask = np.full(np.shape(data_burst), False)
#sgramModel = SgramModel(pulseModel, spectraModel, sgram_fn_vec, 
#                        mask=sgram_mask, clip_fac=bd.clip_fac, other_param_names=["DM"])

sgramModel = SgramModel(pulseModel, spectraModel, sgram_fn, 
                        mask=sgram_mask, clip_fac=bd.clip_fac)#, other_param_names=["DM"])

#sgram_bounds=((0, 0.45, 0, -np.inf),(np.inf, 0.55, np.inf, np.inf)) # did not work when only set up bounds but do not chop data 

# Provide basic candidate information to `BurstFit`: sgram, model, DM, width, RFI mask, etc 
# initial fit: use heimdall results 
bf = BurstFit(
    sgram_model=sgramModel,
    sgram=data_burst, 
    width=width_heimdall,
    dm=dm_heimdall,
    foff=bd.foff * 1024 / nfreq,
    fch1=bd.fch1,
    tsamp=bd.tsamp,
    clip_fac=bd.clip_fac,
    mask= sgram_mask, 
    mcmcfit=False
)

print('bf.ncomponents=%d'%bf.ncomponents)
print(data_burst)

# Some setting up before we do the fitting 
bf.validate()
bf.precalc()
# Out:
# 2022-02-15 19:53:17,231 - prepare_data -burstfit.data - INFO - Preparing data for burst fitting.
# 2022-02-15 19:53:17,235 - get_chunk -root - INFO - Padding with median in the beginning
# 2022-02-15 19:53:17,494 - crop_dedispersed_data -burstfit.data - INFO - Cropping data with time_window: 0.2s.
# 2022-02-15 19:53:17,497 - normalise_data -burstfit.data - INFO - Normalising data using off pulse mean and std.
# 2022-02-15 19:53:17,554 - normalise_data -burstfit.data - INFO - Off pulse mean and std are: (38.87509536428174, 19.181800212420733)
# 8
# bf.ncomponents=0
# [[ 0.          0.          0.         ...  0.          0.
#    0.        ]
#  [-0.29423064  1.8573309   0.75396603 ...  2.7216334   1.2872591
#   -0.9194707 ]
#  [ 0.6068507   0.9010813   1.3424273  ...  0.77235544  0.29423064
#    0.05516824]
#  ...
#  [-0.68040836 -2.298677    1.8021626  ...  2.0228357  -0.7355766
#    0.34939888]
#  [-0.11033649 -0.77235544 -1.3608167  ...  1.728605   -1.4343743
#    0.6068507 ]
#  [ 0.          0.          0.         ...  0.          0.
#    0.        ]]
# 2022-02-15 19:53:50,387 - fitcycle -burstfit.fit - INFO - Fitting component 1.
# 2022-02-15 19:53:50,389 - initial_profilefit -burstfit.fit - INFO - Running initial profile fit for component: 1
# 2022-02-15 19:53:50,417 - initial_profilefit -burstfit.fit - INFO - Converged parameters (profile fit) are:
# 2022-02-15 19:53:50,420 - initial_profilefit -burstfit.fit - INFO - S: 151.70594233063406 +- 17.725889265115303
# 2022-02-15 19:53:50,422 - initial_profilefit -burstfit.fit - INFO - mu_t: 192.09444753614002 +- 0.3480872646532057
# 2022-02-15 19:53:50,424 - initial_profilefit -burstfit.fit - INFO - sigma_t: 7.170721955778954 +- 0.14945068113359525
# 2022-02-15 19:53:50,426 - initial_profilefit -burstfit.fit - INFO - tau: 1.2061029159822192 +- 0.02336997493783004
# 2022-02-15 19:53:50,617 - make_spectra -burstfit.fit - INFO - Making spectra using profile fit parameters.
# 2022-02-15 19:53:50,621 - initial_spectrafit -burstfit.fit - INFO - Running spectra profile fit for component: 1
# 2022-02-15 19:53:50,630 - initial_spectrafit -burstfit.fit - INFO - Converged parameters (spectra fit) are:
# 2022-02-15 19:53:50,633 - initial_spectrafit -burstfit.fit - INFO - mu_f: 3.9413585363140387 +- 0.4154033071854699
# 2022-02-15 19:53:50,635 - initial_spectrafit -burstfit.fit - INFO - sigma_f: 1.9653216972726266 +- 0.348634921587173
# 2022-02-15 19:53:50,808 - sgram_fit -burstfit.fit - INFO - Running sgram profile fit for component: 1
# 2022-02-15 19:53:50,810 - sgram_fit -burstfit.fit - INFO - initial estimate for parameters: [3.9413585363140387, 1.9653216972726266, 151.70594233063406, 192.09444753614002, 7.170721955778954, 1.2061029159822192, 759.7]
# 2022-02-15 19:53:50,913 - sgram_fit -burstfit.fit - INFO - Converged parameters are:
# 2022-02-15 19:53:50,916 - sgram_fit -burstfit.fit - INFO - mu_f: 3.8657528484393624 +- 0.25041109055296495
# 2022-02-15 19:53:50,918 - sgram_fit -burstfit.fit - INFO - sigma_f: 1.9723983922933208 +- 0.22292871612388362
# 2022-02-15 19:53:50,921 - sgram_fit -burstfit.fit - INFO - S: 158.2488940713293 +- 6.698574320789029
# 2022-02-15 19:53:50,924 - sgram_fit -burstfit.fit - INFO - mu_t: 190.11684129026543 +- 1.0479167902300695
# 2022-02-15 19:53:50,926 - sgram_fit -burstfit.fit - INFO - sigma_t: 7.231097837454924 +- 0.038829289698855
# 2022-02-15 19:53:50,928 - sgram_fit -burstfit.fit - INFO - tau: 1.1294142766473119 +- 0.008635347900384543
# 2022-02-15 19:53:50,931 - sgram_fit -burstfit.fit - INFO - DM: 760.6906532140946 +- 1.0064862380154977
# 2022-02-15 19:53:51,457 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:53:51,460 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 19:53:51,464 - get_off_pulse_region -burstfit.fit - INFO - mu_t and sigma_t found in params. Using those to estimate off pulse region.
# 2022-02-15 19:53:51,467 - get_off_pulse_region -burstfit.fit - INFO - Using sgram fit parameters.
# 2022-02-15 19:53:51,469 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:53:51,471 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 19:53:51,475 - calc_redchisq -burstfit.fit - INFO - Reduced chi-square value of fit is: 0.9946609315540181
# 2022-02-15 19:53:51,477 - run_tests -burstfit.fit - INFO - Running statistical tests on the residual.
# 2022-02-15 19:53:51,479 - run_tests -burstfit.fit - INFO - Running off pulse - off pulse test
# 2022-02-15 19:53:51,483 - tests -root - INFO - P values: T-test (0.99111), Kruskal (0.75354), KS (0.97261), F-test (0.47932)
# 2022-02-15 19:53:51,485 - run_tests -burstfit.fit - INFO - Running on pulse - off pulse (L) test
# 2022-02-15 19:53:51,489 - tests -root - INFO - P values: T-test (0.00000), Kruskal (0.00003), KS (0.00001), F-test (0.00439)
# 2022-02-15 19:53:51,492 - run_tests -burstfit.fit - INFO - Running on pulse - off pulse (R) test
# 2022-02-15 19:53:51,496 - tests -root - INFO - P values: T-test (0.00000), Kruskal (0.00001), KS (0.00016), F-test (0.00510)
# 2022-02-15 19:53:51,499 - fitcycle -burstfit.fit - INFO - Fitting component 1.
# 2022-02-15 19:53:51,501 - initial_profilefit -burstfit.fit - INFO - Running initial profile fit for component: 1
# 2022-02-15 19:53:51,532 - initial_profilefit -burstfit.fit - INFO - Converged parameters (profile fit) are:
# 2022-02-15 19:53:51,533 - initial_profilefit -burstfit.fit - INFO - S: 151.70594233063406 +- 17.725889265115303
# 2022-02-15 19:53:51,535 - initial_profilefit -burstfit.fit - INFO - mu_t: 192.09444753614002 +- 0.3480872646532057
# 2022-02-15 19:53:51,536 - initial_profilefit -burstfit.fit - INFO - sigma_t: 7.170721955778954 +- 0.14945068113359525
# 2022-02-15 19:53:51,538 - initial_profilefit -burstfit.fit - INFO - tau: 1.2061029159822192 +- 0.02336997493783004
# 2022-02-15 19:53:51,539 - make_spectra -burstfit.fit - INFO - Making spectra using profile fit parameters.
# 2022-02-15 19:53:51,541 - initial_spectrafit -burstfit.fit - INFO - Running spectra profile fit for component: 1
# 2022-02-15 19:53:51,550 - initial_spectrafit -burstfit.fit - INFO - Converged parameters (spectra fit) are:
# 2022-02-15 19:53:51,552 - initial_spectrafit -burstfit.fit - INFO - mu_f: 3.9413585363140387 +- 0.4154033071854699
# 2022-02-15 19:53:51,555 - initial_spectrafit -burstfit.fit - INFO - sigma_f: 1.9653216972726266 +- 0.348634921587173
# 2022-02-15 19:53:51,557 - sgram_fit -burstfit.fit - INFO - Running sgram profile fit for component: 1
# 2022-02-15 19:53:51,560 - sgram_fit -burstfit.fit - INFO - initial estimate for parameters: [3.9413585363140387, 1.9653216972726266, 151.70594233063406, 192.09444753614002, 7.170721955778954, 1.2061029159822192, 759.7]
# 2022-02-15 19:53:51,679 - sgram_fit -burstfit.fit - INFO - Converged parameters are:
# 2022-02-15 19:53:51,682 - sgram_fit -burstfit.fit - INFO - mu_f: 3.8657528484393624 +- 0.25041109055296495
# 2022-02-15 19:53:51,684 - sgram_fit -burstfit.fit - INFO - sigma_f: 1.9723983922933208 +- 0.22292871612388362
# 2022-02-15 19:53:51,686 - sgram_fit -burstfit.fit - INFO - S: 158.2488940713293 +- 6.698574320789029
# 2022-02-15 19:53:51,688 - sgram_fit -burstfit.fit - INFO - mu_t: 190.11684129026543 +- 1.0479167902300695
# 2022-02-15 19:53:51,691 - sgram_fit -burstfit.fit - INFO - sigma_t: 7.231097837454924 +- 0.038829289698855
# 2022-02-15 19:53:51,692 - sgram_fit -burstfit.fit - INFO - tau: 1.1294142766473119 +- 0.008635347900384543
# 2022-02-15 19:53:51,694 - sgram_fit -burstfit.fit - INFO - DM: 760.6906532140946 +- 1.0064862380154977
# 2022-02-15 19:53:51,695 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:53:51,696 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 19:53:51,700 - get_off_pulse_region -burstfit.fit - INFO - mu_t and sigma_t found in params. Using those to estimate off pulse region.
# 2022-02-15 19:53:51,702 - get_off_pulse_region -burstfit.fit - INFO - Using sgram fit parameters.
# 2022-02-15 19:53:51,704 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:53:51,706 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 19:53:51,710 - calc_redchisq -burstfit.fit - INFO - Reduced chi-square value of fit is: 0.9946609315540181
# 2022-02-15 19:53:51,712 - run_tests -burstfit.fit - INFO - Running statistical tests on the residual.
# 2022-02-15 19:53:51,714 - run_tests -burstfit.fit - INFO - Running off pulse - off pulse test
# 2022-02-15 19:53:51,718 - tests -root - INFO - P values: T-test (0.99111), Kruskal (0.75354), KS (0.97261), F-test (0.47932)
# 2022-02-15 19:53:51,720 - run_tests -burstfit.fit - INFO - Running on pulse - off pulse (L) test
# 2022-02-15 19:53:51,724 - tests -root - INFO - P values: T-test (0.71274), Kruskal (0.04827), KS (0.00000), F-test (0.19802)
# 2022-02-15 19:53:51,726 - run_tests -burstfit.fit - INFO - On pulse residual is similar to left off pulse region.
# 2022-02-15 19:53:51,727 - run_tests -burstfit.fit - INFO - Running on pulse - off pulse (R) test
# 2022-02-15 19:53:51,731 - tests -root - INFO - P values: T-test (0.72126), Kruskal (0.13302), KS (0.00000), F-test (0.21275)
# 2022-02-15 19:53:51,733 - run_tests -burstfit.fit - INFO - On pulse residual is similar to right off pulse region.
# 2022-02-15 19:53:51,735 - fitall -burstfit.fit - INFO - On pulse residual looks like noise. Terminating individual component fitting.
# 2022-02-15 19:53:51,737 - fitall -burstfit.fit - INFO - Final number of components = 1. Terminating fitting.
# 2022-02-15 19:53:51,739 - get_off_pulse_region -burstfit.fit - INFO - mu_t and sigma_t found in params. Using those to estimate off pulse region.
# 2022-02-15 19:53:51,741 - get_off_pulse_region -burstfit.fit - INFO - Using sgram all-component-fit parameters.
# 2022-02-15 19:53:51,743 - get_off_pulse_region -burstfit.fit - INFO - mu_t and sigma_t found in params. Using those to estimate off pulse region.
# 2022-02-15 19:53:51,745 - get_off_pulse_region -burstfit.fit - INFO - Using sgram all-component-fit parameters.
# 2022-02-15 19:53:51,746 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:53:51,748 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 19:53:51,753 - calc_redchisq -burstfit.fit - INFO - Reduced chi-square value of fit is: 0.9946609315540181
# 2022-02-15 19:53:53,706 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:53:53,709 - model -burstfit.fit - INFO - Found 1 components.
# expected despersion in tsamp: 1.4 time samples
# 2022-02-15 19:53:53,916 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 19:53:53,919 - model -burstfit.fit - INFO - Found 1 components.
# 7

# %%
bf.fitcycle(plot=True)
# fit all componnts 
bf.fitall(plot=False) 
bf.calc_redchisq()
plot_fit_results(bf.sgram, bf.sgram_model.evaluate, bf.sgram_params['all'][1]['popt'], 
                 bf.tsamp, bf.fch1, bf.foff, show=True, save=True, outname=save_name+'2d_fit_res_curvfit', outdir=save_dir)
#dm_fit, dm_fit_err = bf.sgram_params['all'][1]['popt'][-1], bf.sgram_params['all'][1]['perr'][-1]

bf.sgram_params
plot_me(bf.model[:,int(382/2-30): int(382/2+30)]) 
bd.tsamp*3*1e3

dm_diff = 103.46597098341815 - 103
print('expected despersion in tsamp: %.1f time samples'%(4.149e3*dm_diff*(1/1280**2 - 1/1530**2) / bd.tsamp)) 

plot_me(bf.model)

bf.sgram_params

sgramModel.nparams

# %%
# MCMC 
# nwalker >= dimention + 1 
# nstep until getting smooth parameter distributions 
mcmc_kwargs = {}
mcmc_kwargs = {'nwalkers':60, 'nsteps':10000,
           'skip':500, 'ncores':4, 
           'start_pos_dev':0.01,
           'prior_range':0.8, 
           'save_results':True,
           'outname':'test_file'}

bf.run_mcmc(plot=True, **mcmc_kwargs)
# Out:
# 2022-02-15 20:11:57,315 - set_initial_pos -root - INFO - Setting initial positions for MCMC.
# 2022-02-15 20:11:57,319 - set_initial_pos -burstfit.mcmc - INFO - Initial guess for MCMC is: [  3.86575285   1.97239839 158.24889407 190.11684129   7.23109784
#    1.12941428 760.69065321]
# 2022-02-15 20:11:57,322 - set_priors -burstfit.mcmc - INFO - Setting priors for MCMC.
# 2022-02-15 20:11:57,325 - set_priors -burstfit.mcmc - INFO - Found tau in param_names. Setting its min value of prior to 0.
# 2022-02-15 20:11:57,327 - set_priors -burstfit.mcmc - INFO - Found sigma_t in param_names. Setting its min value of prior to 0.
# 2022-02-15 20:11:57,328 - set_priors -burstfit.mcmc - INFO - Found sigma_t and tau in param_names. Setting its max value of prior to 2*(max_tau_prior(2.0329456979651614) + max_sigma_t_prior(13.015976107418863))
# 2022-02-15 20:11:57,330 - set_priors -burstfit.mcmc - INFO - Found S and sigma_t in param_names. Setting its max value of prior to 500*max(ts)*max_sigma_t_prior. Setting its min value of prior to 0.
# 2022-02-15 20:11:57,332 - set_priors -burstfit.mcmc - INFO - Found mu_f in param_names. Setting its priors to (-2*nf, 3*nf)
# 2022-02-15 20:11:57,334 - set_priors -burstfit.mcmc - INFO - Found sigma_f in param_names. Setting its priors to (0, 5*nf)
# 2022-02-15 20:11:57,343 - run_mcmc -burstfit.mcmc - INFO - Running MCMC with the following parameters: nwalkers=60, nsteps=10000, start_pos_dev=0.01, ncores=4, skip=500
# 2022-02-15 20:11:57,344 - run_mcmc -burstfit.mcmc - INFO - Priors used in MCMC are:
# 2022-02-15 20:11:57,346 - run_mcmc -burstfit.mcmc - INFO - mu_f_1: [-16.0, 24.0]
# 2022-02-15 20:11:57,348 - run_mcmc -burstfit.mcmc - INFO - sigma_f_1: [0.0, 40.0]
# 2022-02-15 20:11:57,350 - run_mcmc -burstfit.mcmc - INFO - S_1: [0.0, 93887.45450321712]
# 2022-02-15 20:11:57,352 - run_mcmc -burstfit.mcmc - INFO - mu_t_1: [38.023368258053075, 342.21031432247776]
# 2022-02-15 20:11:57,354 - run_mcmc -burstfit.mcmc - INFO - sigma_t_1: [0.0, 30.09784361076805]
# 2022-02-15 20:11:57,356 - run_mcmc -burstfit.mcmc - INFO - tau_1: [0.0, 30.09784361076805]
# 2022-02-15 20:11:57,358 - run_mcmc -burstfit.mcmc - INFO - DM_1: [152.13813064281888, 1369.2431757853703]
# 100%|██████████| 10000/10000 [10:55<00:00, 15.26it/s]
# 2022-02-15 20:22:52,796 - get_chain -burstfit.mcmc - INFO - Using autocorrelation time to estimate burnin and thin values.
# 2022-02-15 20:22:53,552 - get_chain -burstfit.mcmc - INFO - Burnin is: 241, thin is: 41
# 2022-02-15 20:22:53,555 - get_chain -burstfit.mcmc - INFO - Discarding 241 steps/iterations.
# 2022-02-15 20:22:53,614 - print_results -burstfit.mcmc - INFO - MCMC fit results are:
# 2022-02-15 20:22:53,617 - print_results -burstfit.mcmc - INFO - mu_f_1: 3.934646323192716 + 0.269 - 0.278
# 2022-02-15 20:22:53,619 - print_results -burstfit.mcmc - INFO - sigma_f_1: 2.109759612327432 + 0.361 - 0.267
# 2022-02-15 20:22:53,621 - print_results -burstfit.mcmc - INFO - S_1: 145.84412355927896 + 22.146 - 18.824
# 2022-02-15 20:22:53,624 - print_results -burstfit.mcmc - INFO - mu_t_1: 188.6892952740419 + 2.141 - 2.104
# 2022-02-15 20:22:53,626 - print_results -burstfit.mcmc - INFO - sigma_t_1: 4.377115919254069 + 0.892 - 0.877
# 2022-02-15 20:22:53,628 - print_results -burstfit.mcmc - INFO - tau_1: 2.0491125512167514 + 1.612 - 1.372
# 2022-02-15 20:22:53,631 - print_results -burstfit.mcmc - INFO - DM_1: 761.0132369128357 + 1.341 - 1.301
# 2022-02-15 20:22:53,633 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 20:22:53,635 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 20:22:53,641 - get_off_pulse_region -burstfit.fit - INFO - mu_t and sigma_t found in params. Using those to estimate off pulse region.
# 2022-02-15 20:22:53,643 - get_off_pulse_region -burstfit.fit - INFO - Using MCMC parameters
# 2022-02-15 20:22:53,644 - model -burstfit.fit - INFO - Making model.
# 2022-02-15 20:22:53,646 - model -burstfit.fit - INFO - Found 1 components.
# 2022-02-15 20:22:53,652 - calc_redchisq -burstfit.fit - INFO - Reduced chi-square value of fit is: 0.989726034864268
# 2022-02-15 20:22:53,654 - plot -burstfit.mcmc - INFO - Plotting MCMC results.
# 2022-02-15 20:22:54,801 - hist2d -root - WARNING - Too few points to create valid contours
# 2022-02-15 20:22:54,870 - hist2d -root - WARNING - Too few points to create valid contours
# 2022-02-15 20:22:54,898 - hist2d -root - WARNING - Too few points to create valid contours
